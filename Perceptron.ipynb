# %%
import numpy as np
import random, pandas as pd
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
x,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,class_sep=10,random_state=41,hypercube=False)

# %%
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)

# %%
def step(x):
    return 0 if x<0 else 1

# %%
def perceptron(x,y,epochs,lr):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    for i in range(epochs):
        j=np.random.randint(0,100)
        y_pred=step(np.dot(x[j],weights))
        weights=weights+lr*(y[j]-y_pred)*x[j]

    return weights[0],weights[1:]

# %%
bias,coeff=perceptron(x,y,2000,0.1)

# %%
bias,coeff
# Out:
# (np.float64(0.9), array([1.34936352, 0.19978442]))

# %%
m,b=-(coeff[0]/coeff[1]),-bias/coeff[1]

# %%
m,b
# Out:
# (np.float64(-6.754097779006607), np.float64(-4.5048557538080285))

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input+b
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,c='r',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-2.5,2)
# Out:
# (-2.5, 2.0)
